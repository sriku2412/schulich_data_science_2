# %%
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
from oct2py import Oct2Py
oc = Oct2Py()
print(oc.abs(-1))
print(oc.upper('xyz'))
# Out:
# 1.0

# %%
print(oc.upper('xyz'))
# Out:
# XYZ

# %%
oc.plot([1,2,3],'-o', linewidth=2)
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_12672\3852498038.py:1: UserWarning: Key - value pairs are deprecated, use `func_args`
#   oc.plot([1,2,3],'-o', linewidth=2)
# -39.873752632060786

# %%
oc.close()
# Out:
# 1.0

# %%
xx = np.arange(-2*np.pi, 2*np.pi, 0.2)

# %%
oc.surf(np.subtract.outer(np.sin(xx), np.cos(xx)))
# Out:
# -1.4368457993835637

# %%
import numpy as np
import pandas as pd
import sklearn as sl
import scipy as sp
import seaborn as sb
import matplotlib as mpl
from matplotlib import pyplot as plt
import oct2py as oclib

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.24.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (2.1.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.1.3)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mlxtend) (1.3.1)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\lib\site-packages (from mlxtend) (65.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\srika\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.22.0

# %%
josb_assets_list = [101.783,90.671,81.41,77.144,82.515,84.751,88.954,108.457,133.993,186.511,231.83,
                 304.832,368.392,440.098,491.366,556.364,662.037,813.612,894.847,935.738]
mw_assets_list = [160.494,204.105,295.478,379.415,403.732,611.195,707.734,717.869,769.313,869.198,993.322,
               1123.274,1096.952,1256.467,1187.73,1232.106,1320.318,1405.952,1496.347,1555.23]

# %%
year_list = [1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
       2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
plt.figure(figsize=(15,15), dpi= 40)
plt.plot(year_list,josb_assets_list,label="Joseph A Bank",linewidth=8)
plt.plot(year_list,mw_assets_list,'g-.',label="Men's Wearhouse",linewidth=8)
xtick_location = np.arange(1994,2013,4)
plt.xticks(ticks=xtick_location, rotation=0, fontsize=50, horizontalalignment='center')
plt.legend(bbox_to_anchor=(0.50, 0.95),fontsize=14)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.xlabel('Year', fontsize = 14)
plt.ylabel('Total Assets', fontsize = 14)
# Out:
# Text(0, 0.5, 'Total Assets')

# %%
plt.figure(figsize=(24,16), dpi= 40)
random_values = np.random.normal(1000,200,10000)
bins = np.linspace(400,1600,30)
plt.hist(random_values,bins)
plt.xlabel('Total Assets', fontsize=65)
plt.ylabel('Frequency', fontsize = 65)
plt.xticks(fontsize=50)
plt.yticks(fontsize = 50)
plt.grid(axis='both')
plt.title('Histogram of Asset Values in NYSE',fontsize = 65)
# Out:
# Text(0.5, 1.0, 'Histogram of Asset Values in NYSE')

# %%
plt.figure(figsize=(24,16), dpi= 40)
random_values = np.random.normal(1000,200,10000)
bins = np.linspace(400,1600,60)
plt.hist(random_values,bins)
plt.xlabel('Total Assets', fontsize=65)
plt.ylabel('Frequency', fontsize = 65)
plt.xticks(fontsize=50)
plt.yticks(fontsize = 50)
plt.grid(axis='both')
plt.title('Histogram of Asset Values in NYSE',fontsize = 65)
# Out:
# Text(0.5, 1.0, 'Histogram of Asset Values in NYSE')

# %%
list_vec = np.array([1,2,3,4])
list_vec +np.array([1])
# Out:
# array([2, 3, 4, 5])

# %%
matrix_example = np.array([[1,2,3],[0,-1,2],[1,0,4]])
array_example = np.array([[1,-2,1]])

# %%
np.dot(array_example,matrix_example)
# Out:
# array([[2, 4, 3]])

# %%
b = np.linalg.inv(matrix_example)

# %%
matrix_example
# Out:
# array([[ 1,  2,  3],
#        [ 0, -1,  2],
#        [ 1,  0,  4]])

# %%
np.transpose(matrix_example)
# Out:
# array([[ 1,  0,  1],
#        [ 2, -1,  0],
#        [ 3,  2,  4]])

# %%
np.linalg.matrix_rank(matrix_example)
# Out:
# 3

# %%
matrix_example
# Out:
# array([[ 1,  2,  3],
#        [ 0, -1,  2],
#        [ 1,  0,  4]])

# %%
matrix_example[0]
# Out:
# array([1, 2, 3])

# %%
matrix_example[:,2]
# Out:
# array([3, 2, 4])

# %%
np.dot(matrix_example[0],matrix_example[:,2])
# Out:
# 19

# %%
matrix_example[1,2]
# Out:
# 2

# %%
np.dot(b,matrix_example)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.random.normal(10,2,[10,3])
# Out:
# array([[10.82847607, 12.65231588,  7.46535723],
#        [ 8.76807956,  8.13447166, 11.22054964],
#        [ 8.33891812, 11.3299595 ,  9.69868936],
#        [ 8.22575419, 10.08561053, 10.36903728],
#        [ 4.90859412,  8.63079461, 12.63618839],
#        [ 9.07166053,  8.93781223, 12.71734989],
#        [ 7.71468051, 10.04906407,  9.32665728],
#        [11.58842286,  6.19947737,  6.82923312],
#        [11.18723162, 10.07907325, 10.1536941 ],
#        [ 8.78454057, 14.40123448, 12.23719279]])

# %%
sp.stats.norm.isf(0.05,40000,10000)
# Out:
# 56448.53626951473

# %%
DataTable = pd.DataFrame(np.random.normal(10,2,[8,3]),columns=list(["columns1","columns2","columns3",]))
DataTable
# Out:
#     columns1   columns2   columns3
# 0   6.942353  12.582464   9.937408
# 1  11.633678  11.043018  13.288821
# 2   8.501685  13.651482   9.119708
# 3   7.803915   6.940202   9.320550
# 4   7.628619   9.825795   8.962110
# 5  11.602963   9.672730  12.283746
# 6  11.526312   8.903111   6.582055
# 7  13.266354   4.901974   9.711266

# %%
input_table = pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-2 york\MBAN 5110 - Predictive Modelling\class 2\sales_data.csv")
input_table.head()
# Out:
#     Order ID  Product ID  Amount (kg) Order Confirm Date  \
# 0  1005781.0   8908023.0      20000.0                NaN
# 1  1005998.0   8909373.0       6297.0                NaN
# 2  1005969.0   8908023.0      20000.0         2020-05-29
# 3  1005969.0   8908023.0      20000.0         2020-05-29
# 4        NaN         NaN          NaN                NaN
#
#   Required Delivery Date
# 0             2020-07-30
# 1             2020-07-15
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
input_table_imputed_partially = input_table.dropna(subset=["Order Confirm Date"])
input_table_imputed_fully = input_table.dropna()
input_table_imputed_partially.head()
# Out:
#     Order ID  Product ID  Amount (kg) Order Confirm Date  \
# 2  1005969.0   8908023.0      20000.0         2020-05-29
# 3  1005969.0   8908023.0      20000.0         2020-05-29
# 5  1006069.0   8902635.0      10000.0         2020-06-16
# 6  1005998.0   8909373.0       6500.0         2020-06-30
# 7  1006067.0   8908023.0      21000.0         2020-06-22
#
#   Required Delivery Date
# 2                    NaN
# 3                    NaN
# 5             2020-08-05
# 6             2020-09-10
# 7             2020-07-07

# %%
import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

shopping_basket = pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-2 york\MBAN 5110 - Predictive Modelling\class 2\small_dataset.csv")
shopping_basket.head()
# Out:
#    Transaction ID             ItemsPurchased
# 0               1         biscuit,bread,milk
# 1               2  biscuit,bread,cereal,milk
# 2               3                  bread,tea
# 3               4             bread,jam,milk
# 4               5                biscuit,tea

# %%
transaction_list = list(shopping_basket["ItemsPurchased"].apply(lambda t:t.split(",")))
encoder = TransactionEncoder().fit(transaction_list)
encoded_transaction_list = encoder.transform(transaction_list)
ideal_format_table = pd.DataFrame(encoded_transaction_list, columns = encoder.columns_)
ideal_format_table.head()
# Out:
#    biscuit  bread  cereal    jam   milk    tea
# 0     True   True   False  False   True  False
# 1     True   True    True  False   True  False
# 2    False   True   False  False  False   True
# 3    False   True   False   True   True  False
# 4     True  False   False  False  False   True

# %%
shopping_basket_v2 = pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-2 york\MBAN 5110 - Predictive Modelling\class 2\small_dataset_v2.csv")
shopping_basket_v2.head()
# Out:
#    Transaction ID ItemsPurchased
# 0               1        biscuit
# 1               1          bread
# 2               1           milk
# 3               2        biscuit
# 4               2          bread

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.data import iris_data
from mlxtend.plotting import plot_decision_regions

# Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = SVC(random_state=0, probability=True)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[2, 1, 1], voting='soft')

# Loading some example data
X, y = iris_data()
X = X[:,[0, 2]]

# Plotting Decision Regions

gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression',
          'Random Forest',
          'RBF kernel SVM',
          'Ensemble']

for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1],
                         repeat=2)):
    clf.fit(X, y)
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X, y=y,
                                clf=clf, legend=2)
    plt.title(lab)

plt.show()
